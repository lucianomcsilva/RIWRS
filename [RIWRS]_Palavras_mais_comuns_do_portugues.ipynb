# %% [markdown]
# <a href="https://colab.research.google.com/github/lucianomcsilva/RIWRS/blob/main/%5BRIWRS%5D_Palavras_mais_comuns_do_portugues.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Analise de palavras de milhares de artigos da uol**

# %%
import urllib.request

texto = []

# f = open ("mario_quitana.txt",'r') # para arquivos locais
# for line in f:
#   texto.append(line)


import pandas as pd
pd_texto = pd.read_json('https://raw.githubusercontent.com/lucianomcsilva/articulistas/main/UolBlogs.json')
texto = texto = ' '.join(pd_texto['content'])
#texto  
texto = texto.lower() # para unicidade
texto = texto.replace('\n','')
texto = texto.replace('.','')
texto = texto.replace(',','')
texto = texto.replace('(','')
texto = texto.replace(')','')
texto = texto.replace('?','')
texto = texto.replace('\'','') # elimina ' e "


  # for i in range(len(texto)):
  #   texto[i] = texto[i].lower() # para unicidade
  #   texto[i] = texto[i].replace('\n','')
  #   texto[i] = texto[i].replace('.','')
  #   texto[i] = texto[i].replace(',','')
  #   texto[i] = texto[i].replace('(','')
  #   texto[i] = texto[i].replace(')','')
  #   texto[i] = texto[i].replace('?','')
  #   texto[i] = texto[i].replace('\'','') # elimina ' e "
  #   texto[i] = texto[i].replace('que','')
  #   texto[i] = texto[i].replace('um','')

# %% [markdown]
# # **Criando dicionário**

# %%
mydict = {}                             

texto = texto.lower()                   
words = texto.split()                 
#print(words)

for word in words:                     
  if word not in mydict.keys():        
    mydict[word] = 1                    # acrescenta a word com o valor 1
  else:                                 # se a entrada já existe 
    mydict[word] =  mydict[word] + 1    # apenas soma 1 ao valor já existente

print(mydict)
# Out:
# {'numa': 1159, 'excursão': 5, 'turística': 3, 'a': 75951, 'foto': 124, 'de': 100959, 'eduardo': 1134, 'bolsonaro': 12562, 'fantasiado': 7, 'sheik': 2, 'árabe': 3, 'ao': 12082, 'lado': 760, 'da': 39556, 'mulher': 276, 'e': 52756, 'filha': 124, 'em': 26871, 'dubai': 8, 'seria': 1420, 'apenas': 2143, 'um': 21298, 'caso': 1962, 'exibicionismo': 3, 'mau': 116, 'gosto': 89, 'no': 22036, 'contexto': 185, 'uma': 16900, 'comitiva': 64, 'oficial': 315, 'do': 47311, 'brasil': 4143, 'evento': 227, 'internacional': 313, 'imagem': 479, 'é': 18800, 'extravagância': 2, 'serviço': 304, 'desmoralização': 20, 'o': 77952, 'governo': 5865, 'decidiu': 311, 'enviar': 76, '69': 9, 'pessoas': 1890, 'entre': 3109, 'setembro': 526, 'outubro': 292, 'gente': 1283, 'nove': 159, 'ministérios': 142, 'presidência': 785, 'incluindo': 188, 'vice-presidente': 265, 'hamilton': 134, 'mourão': 270, 'conta': 1235, 'preliminar': 31, 'que': 66878, 'ainda': 3281, 'deve': 1064, 'subir': 58, 'coisa': 1048, 'custará': 9, 'tesouro': 43, 'nacional': 1587, 'pelo': 6243, 'menos': 1639, 'r$': 1573, '36': 57, 'milhões': 1531, 'só': 2707, 'diárias': 44, 'pretexto': 96, 'vender': 118, 'oportunidades': 64, 'turismo': 50, 'feira': 40, 'negócios': 144, 'montou': 25, 'pavilhão': 2, 'cujo': 134, 'tema': 278, 'floresta': 74, 'amazônica': 19, 'quer': 1062, 'dizer:': 98, 'mesma': 716, 'descaso': 21, 'governamental': 20, 'ajuda': 346, 'destruir': 84, 'usada': 115, 'como': 11347, 'chamariz': 6, 'turistas': 23, 'estrangeiros': 69, 'mote': 19, 'turístico': 5, 'confundiu': 14, 'cabeça': 356, 'alguns': 708, 'integrantes': 229, 'por': 14002, 'exemplo:': 35, 'fotografado': 5, 'praia': 52, 'secretário': 207, 'pesca': 13, 'jorge': 138, 'seif': 2, 'definiu': 33, 'missão': 145, '"trabalho-passeio"': 1, '"top': 5, 'demais"': 16, 'exultoueduardo': 1, 'defendeu': 198, 'tamanho': 203, 'brasileira': 752, 'para': 27680, 'ele': 6868, 'gigantismo': 1, 'delegação': 14, '"sinal': 7, 'prestígio"': 1, 'jurou': 13, 'sua': 5223, 'presença': 212, 'não': 23134, 'custeada': 4, 'com': 21408, 'dinheiro': 734, 'público': 1679, 'será': 1600, 'filho': 672, 'zero': 177, 'três': 1380, 'presidente': 10642, 'voou': 9, 'junto': 459, 'outros': 1456, 'deputados': 710, 'representante': 82, 'frente': 822, 'parlamentar': 324, 'brasil-emirados': 1, 'árabes': 11, 'faria': 241, 'bem': 1599, 'si': 322, 'mesmo': 2985, 'se': 15494, 'exibisse': 2, 'comprovantes': 8, 'pagou': 45, 'viagem': 96, 'família': 770, 'seu': 4945, 'bolso': 62, 'contrário': 472, 'príncipe': 20, 'brasileiro': 854, 'posando': 7, 'dos': 9836, 'mais': 10595, 'conhecidos': 44, 'principados': 1, 'emirados': 3, 'reforçará': 5, 'impressão': 157, 'prole': 9, 'implantaram': 3, 'espécie': 267, 'monarquia': 14, 'nela': 61, 'reina': 16, 'esculhambação': 3, 'acusado': 217, 'relatório': 230, 'final': 1176, 'cpi': 1969, 'covid': 1048, 'votado': 85, 'na': 17223, 'próxima': 232, 'quarta-feira': 443, 'ter': 3173, 'praticado': 11, '11': 355, 'crimes': 481, 'durante': 1049, 'pandemia': 2582, 'agora': 2303, 'está': 4806, 'medo': 321, 'tudo': 1734, 'fazer': 2120, 'papel': 421, 'vitimanunca': 1, 'república': 2105, 'foi': 7968, 'tantos': 126, 'tão': 801, 'graves': 114, 'tempo': 1736, 'ver': 861, 'relação': 815, 'abaixo': 231, 'exercício': 148, 'mandato': 373, 'podem': 746, 'reparar:': 2, 'sempre': 1238, 'situação': 708, 'aperta': 8, 'dele': 652, 'capitão': 638, 'valentão': 11, 'corre': 147, 'os': 15720, 'quartéis': 60, 'ou': 5353, 'templosesta': 1, 'semana': 1241, 'prestígio': 38, 'militares': 993, 'anda': 71, 'baixa': 143, 'depois': 1981, 'fuzuê': 1, 'golpista': 230, '7': 484, 'recorreu': 40, 'vez': 1889, 'aos': 2847, 'pastores': 35, 'amigosnum': 1, 'encontro': 347, 'organizado': 66, 'pela': 4540, 'igreja': 109, 'evangélica': 37, 'comunidade': 109, 'das': 5688, 'nações': 148, 'brasília': 601, 'pediu': 359, 'piedade:"quantas': 1, 'vezes': 752, 'eu': 2052, 'choro': 28, 'banheiro': 30, 'casa': 1502, 'minha': 674, 'esposa': 58, 'nunca': 906, 'viu': 269, 'ela': 1608, 'acha': 232, 'sou': 303, ' ...

# %%
sorted(mydict.items(), key=lambda x: -x[1])[0:30]
# Out:
# [('de', 100959),
#  ('o', 77952),
#  ('a', 75951),
#  ('que', 66878),
#  ('e', 52756),
#  ('do', 47311),
#  ('da', 39556),
#  ('para', 27680),
#  ('em', 26871),
#  ('não', 23134),
#  ('no', 22036),
#  ('com', 21408),
#  ('um', 21298),
#  ('é', 18800),
#  ('na', 17223),
#  ('uma', 16900),
#  ('os', 15720),
#  ('se', 15494),
#  ('por', 14002),
#  ('bolsonaro', 12562),
#  ('ao', 12082),
#  ('como', 11347),
#  ('presidente', 10642),
#  ('mais', 10595),
#  ('dos', 9836),
#  ('as', 9774),
#  ('à', 8649),
#  ('foi', 7968),
#  ('mas', 7766),
#  ('ele', 6868)]

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.DataFrame(mydict.items(), columns=['word', 'count']).sort_values('count',ascending=False)
#df = df[df['count'] > 100] 

df = df[0:100]
df
# Out:
#         word   count
# 5         de  100959
# 40         o   77952
# 3          a   75951
# 59       que   66878
# 15         e   52756
# ...      ...     ...
# 235      vez    1889
# 1649  câmara    1848
# 7629   trump    1822
# 1334       —    1792
# 1661   nesta    1776
#
# [100 rows x 2 columns]

# %%
plt.figure(figsize=(24,10))
mpl.style.use(['seaborn'])
sns.barplot(x=df.word,y=df['count'])
plt.xticks(rotation=90) 

plt.show()
